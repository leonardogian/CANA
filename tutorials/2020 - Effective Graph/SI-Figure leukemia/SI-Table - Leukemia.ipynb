# %% [markdown]
# # Effective Graph Paper
# Code to generate "SI Table - Canalization measures for variables in the Yest Model"

# %%
import pandas as pd
pd.options.display.float_format = '{:.2g}'.format
import cana
import networkx as nx
from cana.datasets.bio import LEUKEMIA

# %%
L = LEUKEMIA()

# %%
#SG = T.structural_graph()
EG = L.effective_graph(mode='input', bound='mean', threshold=-1)

# %%
bound = 'upper'
df = pd.DataFrame({
        'node':[n.name for n in L.nodes],
        'k':[n.k for n in L.nodes],
        'k_r':[n.input_redundancy(mode='node',bound=bound,norm=False) for n in L.nodes],
        'k_e':[n.effective_connectivity(mode='node',bound=bound,norm=False) for n in L.nodes],
        'k_r*':[n.input_redundancy(mode='node',bound=bound,norm=True) for n in L.nodes],
        'k_e*':[n.effective_connectivity(mode='node',bound=bound,norm=True) for n in L.nodes],
        'k^{out}':[v for n,v in EG.out_degree()],
        'k_e^{out}':[v for n,v in EG.out_degree(weight='weight')],
    }).set_index('node')
df = df[['k','k_r','k_e','k_r*','k_e*','k^{out}','k_e^{out}']]
df['k_e^{out} / k^{out}'] = df['k_e^{out}'] / df['k^{out}']
df.sort_values('k',ascending=False,inplace=True)
display(df)
# Out:
#                         k  k_r  k_e  k_r*  k_e*  k^{out}  k_e^{out}  \
# node
# IFNG                    6  4.6  1.4  0.77  0.23        5        1.7
# JAK                     6  4.5  1.5  0.75  0.25        3          2
# GAP                     5  3.6  1.4  0.71  0.29        2       0.98
# Caspase                 5  3.4  1.6  0.68  0.33        2       0.86
# DISC                    5  3.4  1.6  0.68  0.33        3        1.9
# NFKB                    5  3.5  1.5   0.7   0.3       11        6.5
# BclxL                   5  3.7  1.3  0.74  0.26        1       0.52
# BID                     4  2.6  1.4  0.64  0.36        3        1.3
# FLIP                    4  2.4  1.6  0.61  0.39        2       0.29
# LCK                     4  2.4  1.6  0.61  0.39        1       0.62
# MCL1                    4  2.8  1.2   0.7   0.3        1       0.52
# FasL                    4  2.8  1.2   0.7   0.3        1       0.42
# IL2                     4  2.4  1.6  0.61  0.39        7        2.7
# IFNGT                   3  1.8  1.2  0.58  0.42        1       0.39
# IL2RB                   3  1.5  1.5   0.5   0.5        5        1.9
# Fas                     3  1.8  1.2  0.58  0.42        2       0.94
# IL2RA                   3  1.8  1.2  0.58  0.42        2       0.51
# IL2RAT                  3  1.5  1.5   0.5   0.5        1       0.42
# TRADD                   3  1.8  1.2  0.58  0.42        2       0.29
# P2                      3  1.5  1.5   0.5   0.5        2       0.76
# TPL2                    3  1.5  1.5   0.5   0.5        1       0.57
# GZMB                    3  1.5  1.5   0.5   0.5        3       0.74
# RAS                     3  1.5  1.5   0.5   0.5        3          2
# SOCS                    3  1.8  1.2  0.58  0.42        1        0.6
# GRB2                    2 0.75  1.2  0.38  0.62        2          1
# FYN                     2 0.75  1.2  0.38  0.62        2        1.6
# PDGFR                   2 0.75  1.2  0.38  0.62        4        2.4
# Apoptosis               2 0.75  1.2  0.38  0.62        1       0.62
# IAP                     2 0.75  1.2  0.38  0.62        3       0.88
# Ceramide                2 0.75  1.2  0.38  0.62        2        1.1
# TBET                    2 0.75  1.2  0.38  0.62        5        3.4
# TCR                     2 0.75  1.2  0.38  0.62        3        1.9
# PLCG1                   2 0.75  1.2  0.38  0.62        1       0.38
# ZAP70                   2 0.75  1.2  0.38  0.62        2        1.1
# Proliferation           2 0.75  1.2  0.38  0.62        0          0
# S1P                     2 0.75  1.2  0.38  0.62        3        2.2
# ERK                     2 0.75  1.2  0.38  0.62        3        1.5
# CREB                    2 0.75  1.2  0.38  0.62        2       0.61
# IL2RBT                  2 0.75  1.2  0.38  0.62        1       0.81
# PI3K                    2 0.75  1.2  0.38  0.62        5        2.9
# Stimuli                 1    0    1     0     1        3        1.7
# Stimuli2                1    0    1     0     1        2        1.8
# GPCR                    1    0    1     0     1        1          1
# IL15                    1    0    1     0     1        5        2.3
# CD45                    1    0    1     0     1        3        2.3
# SMAD                    1    0    1     0     1        1       0.39
# SPHK1                   1    0    1     0     1        1       0.62
# PDGF                    1    0    1     0     1        2        1.6
# CTLA4                   1    0    1     0     1        1       0.62
# A20                     1    0    1     0     1        1       0.42
# sFas                    1    0    1     0     1        1       0.42
# FasT                    1    0    1     0     1        3        2.2
# TNF                     1    0    1     0     1        2       0.79
# P27                     1    0    1     0     1        1       0.62
# STAT3                   1    0    1     0     1        8        3.4
# RANTES                  1    0    1     0     1        1      0.095
# NFAT                    1    0    1     0     1        3       0.95
# MEK                     1    0    1     0     1        1       0.62
# Cytoskeleton_signaling  1    0    1     0     1        0          0
# TAX                     1    0    1     0     1        2        1.8
#
#                         k_e^{out} / k^{out}
# node
# IFNG                                   0.34
# JAK                                    0.68
# GAP                                    0.49
# Caspase                                0.43
# DISC                                   0.64
# NFKB                                   0.59
# BclxL                                  0.52
# BID                                    0.43
# FLIP                                   0.15
# LCK                                    0.62
# MCL1                                   0.52
# FasL                                   0.42
# IL2                                    0.39
# IFNGT                                  0.39
# IL2RB                                  0.38
# Fas                                    0.47
# IL2RA                                  0.26
# IL2RAT                                 0.42
# TRADD                                  0.15
# P2                                     0.38
# TPL2                                   0.57
# GZMB                                   0.25
# RAS                                    0.66
# SOCS                                    0.6
# GRB2                                    0.5
# FYN                                    0.81
# PDGFR                                   0.6
# Apoptosis                              0.62
# IAP                                    0.29
# Ceramide                               0.53
# TBET                                   0.68
# TCR                                    0.62
# PLCG1                                  0.38
# ZAP70                                  0.57
# Proliferation                           nan
# S1P                                    0.75
# ERK                                    0.52
# CREB                                   0.31
# IL2RBT                                 0.81
# PI3K                                   0.57
# Stimuli                                0.57
# Stimuli2                               0.91
# GPCR                                      1
# IL15                                   0.47
# CD45                                   0.77
# SMAD                                   0.39
# SPHK1                                  0.62
# PDGF                                   0.81
# CTLA4                                  0.62
# A20                                    0.42
# sFas                                   0.42
# FasT                                   0.73
# TNF                                     0.4
# P27                                    0.62
# STAT3                                  0.43
# RANTES                                0.095
# NFAT                                   0.32
# MEK                                    0.62
# Cytoskeleton_signaling                  nan
# TAX                                    0.91

# %%
# to Latex
print(df.to_latex(escape=False))
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# {} &  k &  k_r &  k_e &  k_r* &  k_e* &  k^{out} &  k_e^{out} &  k_e^{out} / k^{out} \\
# node                   &    &      &      &       &       &          &            &                      \\
# \midrule
# IFNG                   &  6 &  4.6 &  1.4 &  0.77 &  0.23 &        5 &        1.7 &                 0.34 \\
# JAK                    &  6 &  4.5 &  1.5 &  0.75 &  0.25 &        3 &          2 &                 0.68 \\
# GAP                    &  5 &  3.6 &  1.4 &  0.71 &  0.29 &        2 &       0.98 &                 0.49 \\
# Caspase                &  5 &  3.4 &  1.6 &  0.68 &  0.33 &        2 &       0.86 &                 0.43 \\
# DISC                   &  5 &  3.4 &  1.6 &  0.68 &  0.33 &        3 &        1.9 &                 0.64 \\
# NFKB                   &  5 &  3.5 &  1.5 &   0.7 &   0.3 &       11 &        6.5 &                 0.59 \\
# BclxL                  &  5 &  3.7 &  1.3 &  0.74 &  0.26 &        1 &       0.52 &                 0.52 \\
# BID                    &  4 &  2.6 &  1.4 &  0.64 &  0.36 &        3 &        1.3 &                 0.43 \\
# FLIP                   &  4 &  2.4 &  1.6 &  0.61 &  0.39 &        2 &       0.29 &                 0.15 \\
# LCK                    &  4 &  2.4 &  1.6 &  0.61 &  0.39 &        1 &       0.62 &                 0.62 \\
# MCL1                   &  4 &  2.8 &  1.2 &   0.7 &   0.3 &        1 &       0.52 &                 0.52 \\
# FasL                   &  4 &  2.8 &  1.2 &   0.7 &   0.3 &        1 &       0.42 &                 0.42 \\
# IL2                    &  4 &  2.4 &  1.6 &  0.61 &  0.39 &        7 &        2.7 &                 0.39 \\
# IFNGT                  &  3 &  1.8 &  1.2 &  0.58 &  0.42 &        1 &       0.39 &                 0.39 \\
# IL2RB                  &  3 &  1.5 &  1.5 &   0.5 &   0.5 &        5 &        1.9 &                 0.38 \\
# Fas                    &  3 &  1.8 &  1.2 &  0.58 &  0.42 &        2 &       0.94 &                 0.47 \\
# IL2RA                  &  3 &  1.8 &  1.2 &  0.58 &  0.42 &        2 &       0.51 &                 0.26 \\
# IL2RAT                 &  3 &  1.5 &  1.5 &   0.5 &   0.5 &        1 &       0.42 &                 0.42 \\
# TRADD                  &  3 &  1.8 &  1.2 &  0.58 &  0.42 &        2 &       0.29 &                 0.15 \\
# P2                     &  3 &  1.5 &  1.5 &   0.5 &   0.5 &        2 &       0.76 &                 0.38 \\
# TPL2                   &  3 &  1.5 &  1.5 &   0.5 &   0.5 &        1 &       0.57 &                 0.57 \\
# GZMB                   &  3 &  1.5 &  1.5 &   0.5 &   0.5 &        3 &       0.74 &                 0.25 \\
# RAS                    &  3 &  1.5 &  1.5 &   0.5 &   0.5 &        3 &          2 &                 0.66 \\
# SOCS                   &  3 &  1.8 &  1.2 &  0.58 &  0.42 &        1 &        0.6 &                  0.6 \\
# GRB2                   &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        2 &          1 &                  0.5 \\
# FYN                    &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        2 &        1.6 &                 0.81 \\
# PDGFR                  &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        4 &        2.4 &                  0.6 \\
# Apoptosis              &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        1 &       0.62 &                 0.62 \\
# IAP                    &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        3 &       0.88 &                 0.29 \\
# Ceramide               &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        2 &        1.1 &                 0.53 \\
# TBET                   &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        5 &        3.4 &                 0.68 \\
# TCR                    &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        3 &        1.9 &                 0.62 \\
# PLCG1                  &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        1 &       0.38 &                 0.38 \\
# ZAP70                  &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        2 &        1.1 &                 0.57 \\
# Proliferation          &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        0 &          0 &                  nan \\
# S1P                    &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        3 &        2.2 &                 0.75 \\
# ERK                    &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        3 &        1.5 &                 0.52 \\
# CREB                   &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        2 &       0.61 &                 0.31 \\
# IL2RBT                 &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        1 &       0.81 &                 0.81 \\
# PI3K                   &  2 & 0.75 &  1.2 &  0.38 &  0.62 &        5 &        2.9 &                 0.57 \\
# Stimuli                &  1 &    0 &    1 &     0 &     1 &        3 &        1.7 &                 0.57 \\
# Stimuli2               &  1 &    0 &    1 &     0 &     1 &        2 &        1.8 &                 0.91 \\
# GPCR                   &  1 &    0 &    1 &     0 &     1 &        1 &          1 &                    1 \\
# IL15                   &  1 &    0 &    1 &     0 &     1 &        5 &        2.3 &                 0.47 \\
# CD45                   &  1 &    0 &    1 &     0 &     1 &        3 &        2.3 &                 0.77 \\
# SMAD                   &  1 &    0 &    1 &     0 &     1 &        1 &       0.39 &                 0.39 \\
# SPHK1                  &  1 &    0 &    1 &     0 &     1 &        1 &       0.62 &                 0.62 \\
# PDGF                   &  1 &    0 &    1 &     0 &     1 &        2 &        1.6 &                 0.81 \\
# CTLA4                  &  1 &    0 &    1 &     0 &     1 &        1 &       0.62 &                 0.62 \\
# A20                    &  1 &    0 &    1 &     0 &     1 &        1 &       0.42 &                 0.42 \\
# sFas                   &  1 &    0 &    1 &     0 &     1 &        1 &       0.42 &                 0.42 \\
# FasT                   &  1 &    0 &    1 &     0 &     1 &        3 &        2.2 &                 0.73 \\
# TNF                    &  1 &    0 &    1 &     0 &     1 &        2 &       0.79 &                  0.4 \\
# P27                    &  1 &    0 &    1 &     0 &     1 &        1 &       0.62 &                 0.62 \\
# STAT3                  &  1 &    0 &    1 &     0 &     1 &        8 &        3.4 &                 0.43 \\
# RANTES                 &  1 &    0 &    1 &     0 &     1 &        1 &      0.095 &                0.095 \\
# NFAT                   &  1 &    0 &    1 &     0 &     1 &        3 &       0.95 &                 0.32 \\
# MEK                    &  1 &    0 &    1 &     0 &     1 &        1 &       0.62 &                 0.62 \\
# Cytoskeleton_signaling &  1 &    0 &    1 &     0 &     1 &        0 &          0 &                  nan \\
# TAX                    &  1 &    0 &    1 &     0 &     1 &        2 &        1.8 &                 0.91 \\
# \bottomrule
# \end{tabular}
